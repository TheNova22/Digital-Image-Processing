# %%
import pandas as pd
import numpy as np
from PIL import Image

# %%
img = Image.open('images/cat.jpeg').convert('L').resize((640 // 2,426 // 2))
img
# Out:
# <PIL.Image.Image image mode=L size=320x213 at 0x10FE515E0>

# %%
imgMat = np.array(img)
imgMat
# Out:
# array([[ 30,  30,  34, ..., 114, 113, 112],
#        [ 30,  29,  31, ..., 118, 116, 112],
#        [ 33,  33,  32, ..., 118, 117, 115],
#        ...,
#        [122, 122, 121, ..., 113, 115, 116],
#        [125, 127, 128, ..., 111, 112, 113],
#        [123, 125, 128, ..., 112, 112, 113]], dtype=uint8)

# %%
size = 5
np.linspace(- (size // 2), size // 2, size).astype(int)
# Out:
# array([-2, -1,  0,  1,  2])

# %%
size = 5
def getMedian(i,j,mat):
    p = np.linspace(- (size // 2), size // 2, size).astype(int)
    arr = []
    for dx in p:
        if i + dx >= 0 and i + dx < len(mat):
            for dy in p:
                if j + dy >= 0 and j + dy < len(mat[0]):
                    arr.append(mat[i+dx][j+dy])
    return np.median(arr)

# %%
medMat = imgMat.copy()
for i in range(len(imgMat)):
    for j in range(len(imgMat[0])):
        medMat[i][j] = getMedian(i,j,imgMat)

# %%
final = Image.fromarray(medMat)

# %%
final
# Out:
# <PIL.Image.Image image mode=L size=320x213 at 0x10FE7BDC0>

# %%
final.save('images/median.jpeg')
